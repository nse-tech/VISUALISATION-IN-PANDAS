# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\ELECTION CSV.csv")
df = df.set_index('ID')
df
# Out:
#           State     Apc     Pdp      Lp
# ID
# 1          Abia    8914   22676  327095
# 2       Adamawa  182881  417611  105648
# 3     Akwa Ibom  160620  214012  132683
# 4       Anambra    5111    9036  584621
# 5        Bauchi  316694  426607   27373
# 6       Bayelsa   42572   68818   49975
# 7         Benue  310468  130081  308372
# 8         Borno  252282  190921    7205
# 9   Cross River  130520   95425  179917
# 10        Delta   90183  161600  341866
# 11       Ebonyi   42402   13503  259738
# 12          Edo  144471   89585  331163
# 13        Ekiti  201494   89554   11397
# 14        Enugu    4772   15749  428640
# 15          Fct   90902   74194  281717
# 16        Gombe  146977  319123   26120
# 17          Imo   66406   30234  360495
# 18       Jigawa  421390  386587    1889
# 19       Kaduna  399293  554360  294494
# 20         Kano  517341  131716   28513
# 21      Katsina  482283  489045    6376
# 22        Kebbi  248088  285175   10682
# ...

# %%
df.plot(kind = 'line', subplots = True)
# Out:
# array([<Axes: xlabel='ID'>, <Axes: xlabel='ID'>, <Axes: xlabel='ID'>],
#       dtype=object)

# %%
df.plot(kind = 'line', title = 'Election', xlabel = 'States ID', ylabel = 'Figures')
# Out:
# <Axes: title={'center': 'Election'}, xlabel='States ID', ylabel='Figures'>

# %%
df.plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='ID'>

# %%
df.plot.barh(stacked = True)
# Out:
# <Axes: ylabel='ID'>

# %%
df['Lp'].plot(kind = 'bar', stacked = True, title = 'LP Votes per State', xlabel = 'States ID', ylabel = 'Number of votes')
# Out:
# <Axes: title={'center': 'LP Votes per State'}, xlabel='States ID', ylabel='Number of votes'>

# %%
df['Apc'].plot(kind = 'bar', stacked = True, title = 'APC Votes per State', xlabel = 'States ID', ylabel = 'Number of votes')
# Out:
# <Axes: title={'center': 'APC Votes per State'}, xlabel='States ID', ylabel='Number of votes'>

# %%
df['Pdp'].plot(kind = 'bar', stacked = True, title = 'PDP Votes per State', xlabel = 'States ID', ylabel = 'Number of votes')
# Out:
# <Axes: title={'center': 'PDP Votes per State'}, xlabel='States ID', ylabel='Number of votes'>

# %%
df.plot.hist(bins = 100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.area(figsize = (10,5),title = 'Election', xlabel = 'States ID', ylabel = 'Figures')
# Out:
# <Axes: title={'center': 'Election'}, xlabel='States ID', ylabel='Figures'>
